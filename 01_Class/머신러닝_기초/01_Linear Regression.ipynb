# %%
import matplotlib.pyplot as plt
import pandas as pd

dataset = pd.read_csv('LinearRegressionData.csv')

X = dataset.iloc[:, :-1].values
y = dataset.iloc[:, -1].values

from sklearn.linear_model import LinearRegression
reg = LinearRegression()
reg.fit(X,y)

y_pred = reg.predict(X)

# %%
plt.scatter(X,y, color ='blue')
plt.plot(X, y_pred, color = 'green')
plt.title('Score by hour')
plt.xlabel('hours')
plt.ylabel('score')
plt.show()

print('9시간 공부 했을 때', reg.predict([[9]]))
print(reg.coef_) #기울기
print(reg.intercept_) # y절편
print(f"모델 방정식: y = {reg.coef_[0]} * X + {reg.intercept_}")
# Out:
# 9시간 공부 했을 때 [93.77478776]
# [10.44369694]
# -0.21848470286721522
# 모델 방정식: y = 10.443696940573442 * X + -0.21848470286721522

# %%
y_pred_df = pd.DataFrame(y_pred, columns=['Predicted'])
dataset['Predicted'] = y_pred_df
print(dataset)
# Out:
#     hour  score   Predicted
# 0    0.5     10    5.003364
# 1    1.2      8   12.313952
# 2    1.8     14   18.580170
# 3    2.4     26   24.846388
# 4    2.6     22   26.935127
# 5    3.2     30   33.201346
# 6    3.9     42   40.511933
# 7    4.4     48   45.733782
# 8    4.5     38   46.778152
# 9    5.0     58   52.000000
# 10   5.3     60   55.133109
# 11   5.8     72   60.354958
# 12   6.0     62   62.443697
# 13   6.1     68   63.488067
# 14   6.2     72   64.532436
# 15   6.9     58   71.843024
# 16   7.2     76   74.976133
# 17   8.4     86   87.508570
# 18   8.6     90   89.597309
# 19  10.0    100  104.218485
